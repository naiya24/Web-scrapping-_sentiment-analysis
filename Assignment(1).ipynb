# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

def extract_content_with_formatting(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            title = soup.find('h1', class_='entry-title').text.strip()
            content_div = soup.find('div', class_='td-post-content tagdiv-type')
            if content_div:
                content = [title + '\n\n']
                # Iterate through each child in the content div
                for child in content_div.children:
                    if child.name == 'h1':
                        content.append('\n' + child.text.strip() + '\n')  # Add extra newline for headings
                    elif child.name == 'p':
                        content.append(child.text.strip() + '\n')  # Append paragraphs
                    elif child.name in ['ul', 'ol']:  # Handling lists
                        for li in child.find_all('li'):
                            content.append('- ' + li.text.strip())  # Add a dash for list items
                        content.append('')  # Add an extra newline after a list
                    elif child.name == 'li':  # Direct li without ul or ol
                        content.append('- ' + child.text.strip() + '\n')
                    elif child.text.strip():  # Catch all for any other text-containing tags
                        content.append(child.text.strip() + '\n')
                return '\n'.join(content)
            else:
                return "Content block 'td-ss-main-content' not found."
        else:
            return f"Failed to load page, status code: {response.status_code}"
    except Exception as e:
        return f"Failed to extract due to an error: {str(e)}"

def save_text(filename, content):
    with open(f'{filename}.txt', 'w', encoding='utf-8') as file:
        file.write(content)

def process_urls(excel_path):
    # Load the Excel file
    data = pd.read_excel(excel_path)
    for index, row in data.iterrows():
        url_id = row['URL_ID']
        url = row['URL']
        print(f"Processing: {url_id} from {url}")
        content = extract_content_with_formatting(url)
        save_text(os.path.join("/content/drive/MyDrive/Assignment/IN-OUT", url_id), content)
        print(f"Saved content to {url_id}.txt")

# Specify the path to your Excel file
excel_path = '/content/drive/MyDrive/Assignment/IN-OUT/Input.xlsx'
process_urls(excel_path)
# Out:
# Processing: bctech2011 from https://insights.blackcoffer.com/ml-and-ai-based-insurance-premium-model-to-predict-premium-to-be-charged-by-the-insurance-company/
# Saved content to bctech2011.txt
# Processing: bctech2012 from https://insights.blackcoffer.com/streamlined-integration-interactive-brokers-api-with-python-for-desktop-trading-application/
# Saved content to bctech2012.txt
# Processing: bctech2013 from https://insights.blackcoffer.com/efficient-data-integration-and-user-friendly-interface-development-navigating-challenges-in-web-application-deployment/
# Saved content to bctech2013.txt
# Processing: bctech2014 from https://insights.blackcoffer.com/effective-management-of-social-media-data-extraction-strategies-for-authentication-security-and-reliability/
# Saved content to bctech2014.txt
# Processing: bctech2015 from https://insights.blackcoffer.com/streamlined-trading-operations-interface-for-metatrader-4-empowering-efficient-management-and-monitoring/
# Saved content to bctech2015.txt
# Processing: bctech2016 from https://insights.blackcoffer.com/efficient-aws-infrastructure-setup-and-management-addressing-security-scalability-and-compliance/
# Saved content to bctech2016.txt
# Processing: bctech2017 from https://insights.blackcoffer.com/streamlined-equity-waterfall-calculation-and-deal-management-system/
# Saved content to bctech2017.txt
# Processing: bctech2018 from https://insights.blackcoffer.com/automated-orthopedic-case-report-generation-harnessing-web-scraping-and-ai-integration/
# Saved content to bctech2018.txt
# Processing: bctech2019 from https://insights.blackcoffer.com/streamlining-time-calculation-in-warehouse-management-leveraging-shiphero-api-and-google-bigquery-integration/
# Saved content to bctech2019.txt
# Processing: bctech2020 from https://insights.blackcoffer.com/efficient-database-design-and-management-streamlining-access-and-integration-for-partner-entity-management/
# Saved content to bctech2020.txt
# Processing: bctech2021 from https://insights.blackcoffer.com/automated-campaign-management-system-a-comprehensive-solution-with-linkedin-and-email-integration/
# Saved content to bctech2021.txt
# Processing: bctech2022 from https://insights.blackcoffer.com/ai-driven-data-analysis-ai-tool-using-langchain-for-a-leading-real-estate-and-financing-firm-worldwide/
# Saved content to bctech2022.txt
# Processing: bctech2023 from https://insights.blackcoffer.com/grafana-dashboard-to-visualize-and-analyze-sensors-data/
# Saved content to bctech2023.txt
# Processing: bctech2024 from https://insights.blackcoffer.com/mvp-for-a-software-that-analyses-content-from-audio-pharma-based/
# Saved content to bctech2024.txt
# Processing: bctech2025 from https://insights.blackcoffer.com/data-engineering-and-management-tool-airbyte-with-custom-data-connectors-to-manage-crm-database/
# Saved content to bctech2025.txt
# Processing: bctech2026 from https://insights.blackcoffer.com/text-summarizing-tool-to-scrape-and-summarize-pubmed-medical-papers/
# Saved content to bctech2026.txt
# Processing: bctech2027 from https://insights.blackcoffer.com/7up7down-10updown-snakes-and-ladder-games-built-using-oops/
# Saved content to bctech2027.txt
# Processing: bctech2028 from https://insights.blackcoffer.com/data-studio-dashboard-with-a-data-pipeline-tool-synced-with-podio-using-custom-webhooks-and-google-cloud-function/
# Saved content to bctech2028.txt
# Processing: bctech2029 from https://insights.blackcoffer.com/end-to-end-tool-to-optimize-routing-and-planning-of-field-engineers-using-googles-cvrp-tw-algorithm/
# Saved content to bctech2029.txt
# Processing: bctech2030 from https://insights.blackcoffer.com/end-to-end-tool-to-predict-biofuel-prices-using-ieso-data/
# Saved content to bctech2030.txt
# Processing: bctech2031 from https://insights.blackcoffer.com/etl-discovery-tool-using-llma-langchain-openai/
# Saved content to bctech2031.txt
# Processing: bctech2032 from https://insights.blackcoffer.com/gpt-ocr-api/
# Saved content to bctech2032.txt
# Processing: bctech2033 from https://insights.blackcoffer.com/dockerize-the-aws-lambda-for-serverless-architecture/
# Saved content to bctech2033.txt
# Processing: bctech2034 from https://insights.blackcoffer.com/design-and-develop-a-product-recommendation-engine-based-on-the-features-of-products/
# Saved content to bctech2034.txt
# Processing: bctech2035 from https://insights.blackcoffer.com/database-discovery-tool-using-openai/
# Saved content to bctech2035.txt
# Processing: bctech2036 from https://insights.blackcoffer.com/automate-the-data-management-process/
# Saved content to bctech2036.txt
# Processing: bctech2037 from https://insights.blackcoffer.com/realtime-kibana-dashboard-for-a-financial-tech-firm/
# Saved content to bctech2037.txt
# Processing: bctech2038 from https://insights.blackcoffer.com/data-management-etl-and-data-automation/
# Saved content to bctech2038.txt
# Processing: bctech2039 from https://insights.blackcoffer.com/data-management-egeas/
# Saved content to bctech2039.txt
# Processing: bctech2040 from https://insights.blackcoffer.com/design-and-develop-powershell-script/
# Saved content to bctech2040.txt
# Processing: bctech2041 from https://insights.blackcoffer.com/design-and-develop-jenkins-shared-library/
# Saved content to bctech2041.txt
# Processing: bctech2042 from https://insights.blackcoffer.com/design-and-develop-retool-app-for-wholecell-io-and-asana-data-using-their-apis/
# Saved content to bctech2042.txt
# Processing: bctech2043 from https://insights.blackcoffer.com/design-and-develop-a-retool-app-that-will-show-stock-and-crypto-related-information-using-iex-api/
# Saved content to bctech2043.txt
# Processing: bctech2044 from https://insights.blackcoffer.com/crm-monday-com-make-com-to-data-warehouse-to-klipfolio-dashboard/
# Saved content to bctech2044.txt
# Processing: bctech2045 from https://insights.blackcoffer.com/ner-task-using-bert-with-data-in-xml-format/
# Saved content to bctech2045.txt
# Processing: bctech2046 from https://insights.blackcoffer.com/qualtrics-api-integration-using-python/
# Saved content to bctech2046.txt
# Processing: bctech2047 from https://insights.blackcoffer.com/design-and-develop-mlops-framework-for-data-centric-ai/
# Saved content to bctech2047.txt
# Processing: bctech2048 from https://insights.blackcoffer.com/nlp-based-approach-for-data-transformation/
# Saved content to bctech2048.txt
# Processing: bctech2049 from https://insights.blackcoffer.com/an-etl-tool-to-pull-data-from-shiphero-to-google-bigquery-data-warehouse/
# Saved content to bctech2049.txt
# Processing: bctech2050 from https://insights.blackcoffer.com/plaid-financial-analytics-a-data-driven-dashboard-to-generate-insights/
# Saved content to bctech2050.txt
# Processing: bctech2051 from https://insights.blackcoffer.com/recommendation-engine-for-insurance-sector-to-expand-business-in-the-rural-area/
# Saved content to bctech2051.txt
# Processing: bctech2052 from https://insights.blackcoffer.com/data-from-crm-via-zapier-to-google-sheets-dynamic-to-powerbi/
# Saved content to bctech2052.txt
# Processing: bctech2053 from https://insights.blackcoffer.com/data-warehouse-to-google-data-studio-looker-dashboard/
# Saved content to bctech2053.txt
# Processing: bctech2054 from https://insights.blackcoffer.com/crm-monday-com-via-zapier-to-power-bi-dashboard/
# Saved content to bctech2054.txt
# Processing: bctech2055 from https://insights.blackcoffer.com/monday-com-to-kpi-dashboard-to-manage-view-and-generate-insights-from-the-crm-data/
# Saved content to bctech2055.txt
# Processing: bctech2056 from https://insights.blackcoffer.com/data-management-for-a-political-saas-application/
# Saved content to bctech2056.txt
# Processing: bctech2057 from https://insights.blackcoffer.com/google-lsa-ads-google-local-service-ads-etl-tools-and-dashboards/
# Saved content to bctech2057.txt
# Processing: bctech2058 from https://insights.blackcoffer.com/ad-networks-marketing-campaign-data-dashboard-in-looker-google-data-studio/
# Saved content to bctech2058.txt
# Processing: bctech2059 from https://insights.blackcoffer.com/analytical-solution-for-a-tech-firm/
# Saved content to bctech2059.txt
# Processing: bctech2060 from https://insights.blackcoffer.com/ai-solution-for-a-technology-information-and-internet-firm/
# Saved content to bctech2060.txt
# Processing: bctech2061 from https://insights.blackcoffer.com/ai-and-nlp-based-solutions-to-automate-data-discovery-for-venture-capital-and-private-equity-principals/
# Saved content to bctech2061.txt
# Processing: bctech2062 from https://insights.blackcoffer.com/an-etl-solution-for-an-internet-publishing-firm/
# Saved content to bctech2062.txt
# Processing: bctech2063 from https://insights.blackcoffer.com/ai-based-algorithmic-trading-bot-for-forex/
# Saved content to bctech2063.txt
# Processing: bctech2064 from https://insights.blackcoffer.com/equity-waterfalls-model-based-saas-application-for-real-estate-sector/
# Saved content to bctech2064.txt
# Processing: bctech2065 from https://insights.blackcoffer.com/ai-solutions-for-foreign-exchange-an-automated-algo-trading-tool/
# Saved content to bctech2065.txt
# Processing: bctech2066 from https://insights.blackcoffer.com/ai-agent-development-and-deployment-in-jina-ai/
# Saved content to bctech2066.txt
# Processing: bctech2067 from https://insights.blackcoffer.com/golden-record-a-knowledge-graph-database-approach-to-unfold-discovery-using-neo4j/
# Saved content to bctech2067.txt
# Processing: bctech2068 from https://insights.blackcoffer.com/advanced-ai-for-trading-automation/
# Saved content to bctech2068.txt
# Processing: bctech2069 from https://insights.blackcoffer.com/create-a-knowledge-graph-to-provide-real-time-analytics-recommendations-and-a-single-source-of-truth/
# Saved content to bctech2069.txt
# Processing: bctech2070 from https://insights.blackcoffer.com/advanced-ai-for-thermal-person-detection/
# Saved content to bctech2070.txt
# Processing: bctech2071 from https://insights.blackcoffer.com/advanced-ai-for-road-cam-threat-detection/
# Saved content to bctech2071.txt
# Processing: bctech2072 from https://insights.blackcoffer.com/advanced-ai-for-pedestrian-crossing-safety/
# Saved content to bctech2072.txt
# Processing: bctech2073 from https://insights.blackcoffer.com/handgun-detection-using-yolo/
# Saved content to bctech2073.txt
# Processing: bctech2074 from https://insights.blackcoffer.com/using-graph-technology-to-create-single-customer-view/
# Saved content to bctech2074.txt
# Processing: bctech2075 from https://insights.blackcoffer.com/car-detection-in-satellite-images/
# Saved content to bctech2075.txt
# Processing: bctech2076 from https://insights.blackcoffer.com/building-a-physics-informed-neural-network-for-circuit-evaluation/
# Saved content to bctech2076.txt
# Processing: bctech2077 from https://insights.blackcoffer.com/connecting-mongodb-database-to-power-bi-dashboard-dashboard-automation/
# Saved content to bctech2077.txt
# Processing: bctech2078 from https://insights.blackcoffer.com/data-transformation/
# Saved content to bctech2078.txt
# Processing: bctech2079 from https://insights.blackcoffer.com/e-commerce-store-analysis-purchase-behavior-ad-spend-conversion-traffic-etc/
# Saved content to bctech2079.txt
# Processing: bctech2080 from https://insights.blackcoffer.com/kpi-dashboard-for-accountants/
# Saved content to bctech2080.txt
# Processing: bctech2081 from https://insights.blackcoffer.com/return-on-advertising-spend-dashboard-marketing-automation-and-analytics-using-etl-and-dashboard/
# Saved content to bctech2081.txt
# Processing: bctech2082 from https://insights.blackcoffer.com/ranking-customer-behaviours-for-business-strategy/
# Saved content to bctech2082.txt
# Processing: bctech2083 from https://insights.blackcoffer.com/algorithmic-trading-for-multiple-commodities-markets-like-forex-metals-energy-etc/
# Saved content to bctech2083.txt
# Processing: bctech2084 from https://insights.blackcoffer.com/trading-bot-for-forex/
# Saved content to bctech2084.txt
# Processing: bctech2085 from https://insights.blackcoffer.com/python-model-for-the-analysis-of-sector-specific-stock-etfs-for-investment-purposes%ef%bf%bc/
# Saved content to bctech2085.txt
# Processing: bctech2086 from https://insights.blackcoffer.com/medical-classification/
# Saved content to bctech2086.txt
# Processing: bctech2087 from https://insights.blackcoffer.com/design-develop-bert-question-answering-model-explanations-with-visualization/
# Saved content to bctech2087.txt
# Processing: bctech2088 from https://insights.blackcoffer.com/design-and-develop-solution-to-anomaly-detection-classification-problems/
# Saved content to bctech2088.txt
# Processing: bctech2089 from https://insights.blackcoffer.com/an-etl-solution-for-currency-data-to-google-big-query/
# Saved content to bctech2089.txt
# Processing: bctech2090 from https://insights.blackcoffer.com/etl-and-mlops-infrastructure-for-blockchain-analytics/
# Saved content to bctech2090.txt
# Processing: bctech2091 from https://insights.blackcoffer.com/an-agent-based-model-of-a-virtual-power-plant-vpp/
# Saved content to bctech2091.txt
# Processing: bctech2092 from https://insights.blackcoffer.com/transform-api-into-sdk-library-and-widget/
# Saved content to bctech2092.txt
# Processing: bctech2093 from https://insights.blackcoffer.com/integration-of-a-product-to-a-cloud-based-crm-platform/
# Saved content to bctech2093.txt
# Processing: bctech2094 from https://insights.blackcoffer.com/a-web-based-dashboard-for-the-filtered-data-retrieval-of-land-records/
# Saved content to bctech2094.txt
# Processing: bctech2095 from https://insights.blackcoffer.com/integration-of-video-conferencing-data-to-the-existing-web-app/
# Saved content to bctech2095.txt
# Processing: bctech2096 from https://insights.blackcoffer.com/design-develop-an-app-in-retool-which-shows-the-progress-of-the-added-video/
# Saved content to bctech2096.txt
# Processing: bctech2097 from https://insights.blackcoffer.com/auvik-connectwise-integration-in-grafana/
# Saved content to bctech2097.txt
# Processing: bctech2098 from https://insights.blackcoffer.com/data-integration-and-big-data-performance-using-elk-stack/
# Saved content to bctech2098.txt
# Processing: bctech2099 from https://insights.blackcoffer.com/web-data-connector/
# Saved content to bctech2099.txt
# Processing: bctech2100 from https://insights.blackcoffer.com/an-app-for-updating-the-email-id-of-the-user-and-stripe-refund-tool-using-retool/
# Saved content to bctech2100.txt
# Processing: bctech2101 from https://insights.blackcoffer.com/an-ai-ml-based-web-application-that-detects-the-correctness-of-text-in-a-given-video/
# Saved content to bctech2101.txt
# Processing: bctech2102 from https://insights.blackcoffer.com/website-tracking-and-insights-using-google-analytics-google-tag-manager/
# Saved content to bctech2102.txt
# Processing: bctech2103 from https://insights.blackcoffer.com/dashboard-to-track-the-analytics-of-the-website-using-google-analytics-and-google-tag-manager/
# Saved content to bctech2103.txt
# Processing: bctech2104 from https://insights.blackcoffer.com/power-bi-dashboard-on-operations-transactions-and-marketing-embedding-the-dashboard-to-web-app/
# Saved content to bctech2104.txt
# Processing: bctech2105 from https://insights.blackcoffer.com/nft-data-automation-looksrare-and-etl-tool/
# Saved content to bctech2105.txt
# Processing: bctech2106 from https://insights.blackcoffer.com/optimize-the-data-scraper-program-to-easily-accommodate-large-files-and-solve-oom-errors/
# Saved content to bctech2106.txt
# Processing: bctech2107 from https://insights.blackcoffer.com/making-a-robust-way-to-sync-data-from-airtables-to-mongodb-using-python-etl-solution/
# Saved content to bctech2107.txt
# Processing: bctech2108 from https://insights.blackcoffer.com/incident-duration-prediction-infrastructure-and-real-estate/
# Saved content to bctech2108.txt
# Processing: bctech2109 from https://insights.blackcoffer.com/statistical-data-analysis-of-reinforced-concrete/
# Saved content to bctech2109.txt
# Processing: bctech2110 from https://insights.blackcoffer.com/database-normalization-segmentation-with-google-data-studio-dashboard-insights/
# Saved content to bctech2110.txt
# Processing: bctech2111 from https://insights.blackcoffer.com/power-bi-dashboard-to-drive-insights-from-complex-data-to-generate-business-insights/
# Saved content to bctech2111.txt
# Processing: bctech2112 from https://insights.blackcoffer.com/real-time-dashboard-to-monitor-infrastructure-activity-and-machines/
# Saved content to bctech2112.txt
# Processing: bctech2113 from https://insights.blackcoffer.com/electric-vehicles-ev-load-management-system-to-forecast-energy-demand/
# Saved content to bctech2113.txt
# Processing: bctech2114 from https://insights.blackcoffer.com/power-bi-data-driven-map-dashboard/
# Saved content to bctech2114.txt
# Processing: bctech2115 from https://insights.blackcoffer.com/google-local-service-ads-lsa-leads-dashboard/
# Saved content to bctech2115.txt
# Processing: bctech2116 from https://insights.blackcoffer.com/aws-lex-voice-and-chatbot/
# Saved content to bctech2116.txt
# Processing: bctech2117 from https://insights.blackcoffer.com/metabridges-api-decentraland-integration/
# Saved content to bctech2117.txt
# Processing: bctech2118 from https://insights.blackcoffer.com/microsoft-azure-chatbot-with-luis-language-understanding/
# Saved content to bctech2118.txt
# Processing: bctech2119 from https://insights.blackcoffer.com/impact-of-news-media-and-press-on-innovation-startups-and-investments/
# Saved content to bctech2119.txt
# Processing: bctech2120 from https://insights.blackcoffer.com/aws-quicksight-reporting-dashboard/
# Saved content to bctech2120.txt
# Processing: bctech2121 from https://insights.blackcoffer.com/google-data-studio-dashboard-for-marketing-ads-and-traction-data/
# Saved content to bctech2121.txt
# Processing: bctech2122 from https://insights.blackcoffer.com/gangala-in-e-commerce-big-data-etl-elt-solution-and-data-warehouse/
# Saved content to bctech2122.txt
# Processing: bctech2123 from https://insights.blackcoffer.com/big-data-solution-to-an-online-multivendor-marketplace-ecommerce-business/
# Saved content to bctech2123.txt
# Processing: bctech2124 from https://insights.blackcoffer.com/creating-a-custom-report-and-dashboard-using-the-data-got-from-atera-api/
# Saved content to bctech2124.txt
# Processing: bctech2125 from https://insights.blackcoffer.com/azure-data-lake-and-power-bi-dashboard/
# Saved content to bctech2125.txt
# Processing: bctech2126 from https://insights.blackcoffer.com/google-data-studio-pipeline-with-gcp-mysql/
# Saved content to bctech2126.txt
# Processing: bctech2127 from https://insights.blackcoffer.com/quickbooks-dashboard-to-find-patterns-in-finance-sales-and-forecasts/
# Saved content to bctech2127.txt
# Processing: bctech2128 from https://insights.blackcoffer.com/marketing-sales-and-financial-data-business-dashboard-wink-report/
# Saved content to bctech2128.txt
# Processing: bctech2129 from https://insights.blackcoffer.com/react-native-apps-in-the-development-portfolio/
# Saved content to bctech2129.txt
# Processing: bctech2130 from https://insights.blackcoffer.com/a-leading-firm-website-seo-optimization/
# Saved content to bctech2130.txt
# Processing: bctech2131 from https://insights.blackcoffer.com/a-leading-hospitality-firm-in-the-usa-website-seo-optimization/
# Saved content to bctech2131.txt
# Processing: bctech2132 from https://insights.blackcoffer.com/a-leading-firm-in-the-usa-website-seo-optimization/
# Saved content to bctech2132.txt
# Processing: bctech2133 from https://insights.blackcoffer.com/a-leading-musical-instrumental-website-seo-optimization/
# Saved content to bctech2133.txt
# Processing: bctech2134 from https://insights.blackcoffer.com/a-leading-firm-in-the-usa-seo-and-website-optimization/
# Saved content to bctech2134.txt
# Processing: bctech2135 from https://insights.blackcoffer.com/immigration-datawarehouse-ai-based-recommendations/
# Saved content to bctech2135.txt
# Processing: bctech2136 from https://insights.blackcoffer.com/lipsync-automation-for-celebrities-and-influencers/
# Saved content to bctech2136.txt
# Processing: bctech2137 from https://insights.blackcoffer.com/key-audit-matters-predictive-modeling/
# Saved content to bctech2137.txt
# Processing: bctech2138 from https://insights.blackcoffer.com/splitting-of-songs-into-its-vocals-and-instrumental/
# Saved content to bctech2138.txt
# Processing: bctech2139 from https://insights.blackcoffer.com/ai-and-ml-technologies-to-evaluate-learning-assessments/
# Saved content to bctech2139.txt
# Processing: bctech2140 from https://insights.blackcoffer.com/datawarehouse-and-recommendations-engine-for-airbnb/
# Saved content to bctech2140.txt
# Processing: bctech2141 from https://insights.blackcoffer.com/real-estate-data-warehouse/
# Saved content to bctech2141.txt
# Processing: bctech2142 from https://insights.blackcoffer.com/traction-dashboards-of-marketing-campaigns-and-posts/
# Saved content to bctech2142.txt
# Processing: bctech2143 from https://insights.blackcoffer.com/google-local-service-ads-lsa-data-warehouse/
# Saved content to bctech2143.txt
# Processing: bctech2144 from https://insights.blackcoffer.com/google-local-service-ads-missed-calls-and-messages-automation-tool/
# Saved content to bctech2144.txt
# Processing: bctech2145 from https://insights.blackcoffer.com/marketing-ads-leads-call-status-data-tool-to-bigquery/
# Saved content to bctech2145.txt
# Processing: bctech2146 from https://insights.blackcoffer.com/marketing-analytics-to-automate-leads-call-status-and-reporting/
# Saved content to bctech2146.txt
# Processing: bctech2147 from https://insights.blackcoffer.com/callrail-analytics-leads-report-alert/
# Saved content to bctech2147.txt
# Processing: bctech2148 from https://insights.blackcoffer.com/marketing-automation-tool-to-notify-lead-details-to-clients-over-email-and-phone/
# Saved content to bctech2148.txt
# Processing: bctech2149 from https://insights.blackcoffer.com/data-etl-local-service-ads-leads-to-bigquery/
# Saved content to bctech2149.txt
# Processing: bctech2150 from https://insights.blackcoffer.com/marbles-stimulation-using-python/
# Saved content to bctech2150.txt
# Processing: bctech2151 from https://insights.blackcoffer.com/stocktwits-data-structurization/
# Saved content to bctech2151.txt
# Processing: bctech2152 from https://insights.blackcoffer.com/sentimental-analysis-on-shareholder-letter-of-companies/
# Saved content to bctech2152.txt
# Processing: bctech2153 from https://insights.blackcoffer.com/population-and-community-survey-of-america/
# Saved content to bctech2153.txt
# Processing: bctech2154 from https://insights.blackcoffer.com/google-lsa-api-data-automation-and-dashboarding/
# Saved content to bctech2154.txt
# Processing: bctech2155 from https://insights.blackcoffer.com/healthcare-data-analysis/
# Saved content to bctech2155.txt
# Processing: bctech2156 from https://insights.blackcoffer.com/budget-sales-kpi-dashboard-using-power-bi/
# Saved content to bctech2156.txt
# Processing: bctech2157 from https://insights.blackcoffer.com/amazon-buy-bot-an-automation-ai-tool-to-auto-checkouts/
# Saved content to bctech2157.txt

# %%
import pandas as pd
import re
import nltk
import os
from nltk.tokenize import sent_tokenize, word_tokenize

# Download necessary NLTK data
nltk.download('punkt')

# Load Positive and Negative Sentiment Dictionaries
def load_sentiment_dictionary():
    pos_path = '/content/drive/MyDrive/Assignment/positive-words.txt'
    neg_path = '/content/drive/MyDrive/Assignment/negative-words.txt'

    # Load positive words
    with open(pos_path, 'r', encoding='utf-8', errors='replace') as pos_file:
        positive_words = set([line.strip().lower() for line in pos_file.readlines() if line.strip() and not line.startswith(';')])

    # Load negative words
    with open(neg_path, 'r', encoding='utf-8', errors='replace') as neg_file:
        negative_words = set([line.strip().lower() for line in neg_file.readlines() if line.strip() and not line.startswith(';')])

    print(f"Loaded {len(positive_words)} positive words and {len(negative_words)} negative words.")

    return positive_words, negative_words

# Load Stopwords
def load_stopwords(stopwords_folder):
    stopwords = set()
    for stopword_file in os.listdir(stopwords_folder):
        stopword_path = os.path.join(stopwords_folder, stopword_file)  # Corrected here
        try:
            with open(stopword_path, 'r', encoding='utf-8') as file:
                stopwords.update(line.strip().lower() for line in file if line.strip())
        except UnicodeDecodeError:
            with open(stopword_path, 'r', encoding='latin-1') as file:
                stopwords.update(line.strip().lower() for line in file if line.strip())
    return stopwords

# Sentiment analysis function
def sentiment_analysis(text, positive_words, negative_words, stopwords):
    words = [word for word in re.findall(r'\w+', text.lower()) if word not in stopwords and word.isalpha()]
    print(f"Words to analyze: {words}")

    # Initialize scores
    positive_score = 0
    negative_score = 0

    for word in words:
        if word in positive_words:
            print(f"Positive word found: {word}")
            positive_score += 1
        if word in negative_words:
            print(f"Negative word found: {word}")
            negative_score += 1

    return positive_score, negative_score

# Function to calculate readability metrics
def readability_metrics(text, stopwords):
    sentences = sent_tokenize(text)
    words = [word for word in word_tokenize(text.lower()) if word not in stopwords and word.isalpha()]
    word_count = len(words)
    sentence_count = len(sentences)

    avg_sentence_length = word_count / sentence_count if sentence_count > 0 else 0
    complex_words = [word for word in words if syllable_count(word) >= 3]
    percentage_complex_words = len(complex_words) / word_count if word_count > 0 else 0

    fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)

    return avg_sentence_length, percentage_complex_words, fog_index, len(complex_words), word_count

# Function to count syllables in a word
def syllable_count(word):
    vowels = 'aeiou'
    word = word.lower()
    count = 0
    prev_char_was_vowel = False
    for char in word:
        if char in vowels:
            if not prev_char_was_vowel:
                count += 1
            prev_char_was_vowel = True
        else:
            prev_char_was_vowel = False
    if word.endswith('e'):
        count -= 1
    return max(1, count)

# Function to count personal pronouns
def personal_pronouns(text):
    pronouns = ["i", "we", "my", "ours", "us"]
    words = word_tokenize(text.lower())
    return sum(1 for word in words if word in pronouns)

# Function to calculate average word length
def avg_word_length(text):
    words = word_tokenize(text)
    total_length = sum(len(word) for word in words)
    return total_length / len(words) if words else 0

# Analyze and save results function
def analyze_and_save_results(content, url_id, positive_words, negative_words, stopwords):
    positive_score, negative_score = sentiment_analysis(content, positive_words, negative_words, stopwords)
    polarity_score = (positive_score - negative_score) / ((positive_score + negative_score) + 0.000001)
    subjectivity_score = (positive_score + negative_score) / len(re.findall(r'\w+', content)) if content else 0

    avg_sentence_length, percentage_complex_words, fog_index, complex_word_count, word_count = readability_metrics(content, stopwords)
    syllables_per_word = sum([syllable_count(word) for word in word_tokenize(content)]) / word_count if word_count else 0
    pronoun_count = personal_pronouns(content)
    avg_word_len = avg_word_length(content)

    # Create DataFrame for results
    results = {
        'URL_ID': url_id,
        'POSITIVE SCORE': positive_score,
        'NEGATIVE SCORE': negative_score,
        'POLARITY SCORE': polarity_score,
        'SUBJECTIVITY SCORE': subjectivity_score,
        'AVG SENTENCE LENGTH': avg_sentence_length,
        'PERCENTAGE OF COMPLEX WORDS': percentage_complex_words,
        'FOG INDEX': fog_index,
        'COMPLEX WORD COUNT': complex_word_count,
        'WORD COUNT': word_count,
        'SYLLABLE PER WORD': syllables_per_word,
        'PERSONAL PRONOUNS': pronoun_count,
        'AVG WORD LENGTH': avg_word_len
    }

    return results  # Return results instead of saving them directly

# Function to filter URLs
def filter_urls(data, start_id, end_id):
    return data[(data['URL_ID'] >= start_id) & (data['URL_ID'] <= end_id)]

# Example usage
def run_analysis(excel_path, output_excel_path, stopwords_folder):
    positive_words, negative_words = load_sentiment_dictionary()
    stopwords = load_stopwords(stopwords_folder)

    data = pd.read_excel(excel_path)

    # Filter URLs from bctech2021 to bctech2157
    filtered_data = filter_urls(data, 'bctech2021', 'bctech2157')

    all_results = []  # List to hold results for all URLs

    for index, row in filtered_data.iterrows():
        url_id = row['URL_ID']
        url = row['URL']
        print(f"Analyzing content from: {url}")
        content = extract_content_with_formatting(url)  # Call the scraping function
        result = analyze_and_save_results(content, url_id, positive_words, negative_words, stopwords)
        all_results.append(result)  # Append each result to the list

    # Save all results to an Excel file after processing all URLs
    output_df = pd.DataFrame(all_results)
    output_df.to_excel(output_excel_path, index=False)

    print(f"All results saved to {output_excel_path}.")

# Example paths
excel_path = '/content/drive/MyDrive/Assignment/IN-OUT/Input.xlsx'
output_excel_path = '/content/drive/MyDrive/Assignment/Output_Analysis.xlsx'  # Define the output path here

# Run the analysis
run_analysis(excel_path, output_excel_path, '/content/drive/MyDrive/Assignment/Stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Loaded 2006 positive words and 4783 negative words.
# Analyzing content from: https://insights.blackcoffer.com/automated-campaign-management-system-a-comprehensive-solution-with-linkedin-and-email-integration/
# Words to analyze: ['automated', 'campaign', 'management', 'system', 'a', 'comprehensive', 'solution', 'linkedin', 'email', 'integration', 'client', 'background', 'client', 'a', 'leading', 'marketing', 'tech', 'firm', 'worldwide', 'industry', 'type', 'marketing', 'products', 'services', 'ad', 'tech', 'marketing', 'automation', 'lead', 'management', 'organization', 'size', 'problem', 'integrating', 'linkedin', 'email', 'apis', 'automation', 'building', 'a', 'user', 'friendly', 'responsive', 'frontend', 'interface', 'developing', 'a', 'robust', 'backend', 'code', 'campaign', 'automation', 'ensuring', 'secure', 'user', 'authentication', 'data', 'exchange', 'managing', 'campaign', 'creation', 'scheduling', 'tracking', 'handling', 'data', 'storage', 'organization', 'mongodb', 'providing', 'comprehensive', 'documentation', 'users', 'ensuring', 'scalability', 'reliability', 'hosting', 'addressing', 'security', 'privacy', 'concerns', 'maintaining', 'ongoing', 'support', 'updates', 'solution', 'leverage', 'linkedin', 'email', 'api', 'documentation', 'libraries', 'implement', 'a', 'responsive', 'intuitive', 'frontend', 'using', 'react', 'js', 'develop', 'backend', 'code', 'campaign', 'automation', 'python', 'node', 'js', 'utilize', 'secure', 'authentication', 'mechanisms', 'like', 'jwt', 'create', 'user', 'friendly', 'campaign', 'creation', 'management', 'interfaces', 'store', 'manage', 'campaign', 'data', 'efficiently', 'mongodb', 'produce', 'detailed', 'documentation', 'installation', 'usage', 'troubleshooting', 'employ', 'aws', 'scalable', 'reliable', 'hosting', 'implement', 'encryption', 'privacy', 'measures', 'establish', 'a', 'support', 'maintenance', 'plan', 'ongoing', 'updates', 'solution', 'architecture', 'frontend', 'built', 'react', 'js', 'backend', 'using', 'python', 'node', 'js', 'mongodb', 'data', 'storage', 'management', 'aws', 'hosting', 'scalability', 'integration', 'linkedin', 'email', 'apis', 'user', 'authentication', 'authorization', 'layers', 'campaign', 'creation', 'scheduling', 'tracking', 'features', 'responsive', 'user', 'friendly', 'web', 'app', 'interface', 'documentation', 'portal', 'users', 'developers', 'security', 'privacy', 'measures', 'integrated', 'throughout', 'architecture', 'tech', 'tools', 'usedlinkedin', 'api', 'gmail', 'api', 'google', 'account', 'selenium', 'beautifulsoup', 'requests', 'linkedin', 'api', 'gmail', 'api', 'google', 'account', 'selenium', 'beautifulsoup', 'requests', 'language', 'techniques', 'usedpython', 'react', 'js', 'python', 'react', 'js', 'models', 'useddjango', 'orm', 'django', 'orm', 'skills', 'usedpython', 'webscraping', 'react', 'js', 'selenium', 'django', 'django', 'rest', 'framework', 'python', 'webscraping', 'react', 'js', 'selenium', 'django', 'django', 'rest', 'framework', 'databases', 'usedmongodb', 'mongodb', 'web', 'servers', 'usedaws', 'aws', 'technical', 'challenges', 'faced', 'project', 'execution', 'complex', 'integration', 'linkedin', 'email', 'apis', 'designing', 'implementing', 'a', 'responsive', 'frontend', 'developing', 'robust', 'automation', 'logic', 'campaigns', 'ensuring', 'secure', 'authentication', 'data', 'exchange', 'managing', 'datasets', 'data', 'organization', 'mongodb', 'creating', 'comprehensive', 'user', 'friendly', 'documentation', 'scaling', 'application', 'hosting', 'addressing', 'security', 'privacy', 'concerns', 'handling', 'user', 'support', 'requests', 'bug', 'fixes', 'keeping', 'application', 'date', 'api', 'changes', 'technical', 'challenges', 'solved', 'thoroughly', 'studied', 'linkedin', 'email', 'api', 'documentation', 'used', 'react', 'js', 'responsive', 'design', 'practices', 'frontend', 'implemented', 'efficient', 'campaign', 'automation', 'logic', 'employed', 'jwt', 'secure', 'user', 'authentication', 'optimized', 'data', 'storage', 'retrieval', 'mongodb', 'prepared', 'detailed', 'documentation', 'users', 'developers', 'utilized', 'aws', 'services', 'scalable', 'hosting', 'implemented', 'encryption', 'privacy', 'measures', 'es ...
# Positive word found: comprehensive
# Positive word found: leading
# Positive word found: lead
# Negative word found: problem
# Positive word found: friendly
# Positive word found: responsive
# Positive word found: robust
# Positive word found: secure
# Positive word found: comprehensive
# Negative word found: concerns
# Positive word found: support
# Positive word found: leverage
# Positive word found: responsive
# Positive word found: intuitive
# Positive word found: secure
# Positive word found: like
# Positive word found: friendly
# Positive word found: efficiently
# Positive word found: reliable
# Positive word found: support
# Positive word found: responsive
# Positive word found: friendly
# Positive word found: integrated
# Negative word found: complex
# Positive word found: responsive
# Positive word found: robust
# Positive word found: secure
# Positive word found: comprehensive
# Positive word found: friendly
# Negative word found: concerns
# Positive word found: support
# Negative word found: bug
# Positive word found: responsive
# Positive word found: efficient
# Positive word found: secure
# Positive word found: support
# Analyzing content from: https://insights.blackcoffer.com/ai-driven-data-analysis-ai-tool-using-langchain-for-a-leading-real-estate-and-financing-firm-worldwide/
# Words to analyze: ['driven', 'data', 'analysis', 'tool', 'using', 'langchain', 'a', 'leading', 'estate', 'financing', 'firm', 'worldwide', 'client', 'background', 'client', 'a', 'leading', 'estate', 'financing', 'firm', 'worldwide', 'industry', 'type', 'estate', 'products', 'services', 'infrastructure', 'development', 'financing', 'estate', 'organization', 'size', 'problem', 'creating', 'a', 'user', 'friendly', 'data', 'analysis', 'tool', 'capable', 'interpreting', 'natural', 'language', 'queries', 'providing', 'insightful', 'analyses', 'csv', 'data', 'tool', 'facilitate', 'seamless', 'interaction', 'enabling', 'users', 'gain', 'valuable', 'insights', 'without', 'need', 'technical', 'expertise', 'functionalities', 'include', 'data', 'exploration', 'trend', 'identification', 'pattern', 'recognition', 'anomaly', 'detection', 'presented', 'a', 'comprehensible', 'format', 'tool', 'must', 'also', 'ensure', 'efficient', 'handling', 'csv', 'datasets', 'maintaining', 'accuracy', 'reliability', 'analyses', 'solution', 'data', 'ingestion', 'conversion', 'csv', 'data', 'acquired', 'a', 'source', 'local', 'file', 'system', 'storage', 'etc', 'data', 'converted', 'a', 'pandas', 'dataframe', 'using', 'function', 'similar', 'methods', 'provided', 'pandas', 'library', 'data', 'cleaning', 'data', 'cleaning', 'operations', 'performed', 'dataframe', 'serves', 'ideal', 'input', 'pandas', 'agent', 'include', 'column', 'data', 'type', 'conversion', 'handling', 'duplicates', 'handling', 'unnecessary', 'columns', 'etc', 'initialization', 'langchain', 's', 'pandas', 'agent', 'langchain', 's', 'pandas', 'agent', 'initialized', 'necessary', 'parameters', 'parameters', 'include', 'system', 'prompt', 'a', 'custom', 'prompt', 'provided', 'user', 'defined', 'application', 'temperature', 'a', 'parameter', 'controlling', 'randomness', 'model', 's', 'outputs', 'model', 'specific', 'model', 'model', 'configuration', 'used', 'agent', 'relevant', 'parameters', 'based', 'requirements', 'capabilities', 'agent', 'integration', 'pandas', 'dataframe', 'dataframe', 'created', 'previous', 'step', 'serves', 'input', 'pandas', 'agent', 'contains', 'structured', 'data', 'serve', 'input', 'pandas', 'agent', 'natural', 'language', 'query', 'interpretation', 'user', 'interacts', 'system', 'posing', 'queries', 'natural', 'language', 'langchain', 's', 'pandas', 'agent', 'interprets', 'queries', 'using', 'gpt', 'backend', 'converts', 'executable', 'commands', 'operations', 'dataframe', 'dataframe', 'operations', 'pandas', 'agent', 'executes', 'operations', 'needed', 'dataframe', 'operations', 'include', 'filtering', 'selecting', 'rows', 'columns', 'based', 'specified', 'criteria', 'aggregation', 'computing', 'summary', 'statistics', 'aggregating', 'data', 'based', 'groups', 'transformation', 'modifying', 'data', 'dataframe', 'e', 'g', 'adding', 'removing', 'columns', 'changing', 'data', 'types', 'joining', 'merging', 'combining', 'multiple', 'dataframes', 'based', 'common', 'indices', 'sorting', 'arranging', 'rows', 'columns', 'a', 'specified', 'order', 'pandas', 'dataframe', 'operations', 'required', 'user', 'queries', 'delivery', 'end', 'user', 'processed', 'output', 'delivered', 'end', 'user', 'streamlit', 'user', 'interface', 'user', 'review', 'insights', 'provided', 'system', 'refine', 'queries', 'needed', 'solution', 'architecture', 'deliverables', 'data', 'analysis', 'tool', 'streamlit', 'frontend', 'tech', 'tools', 'used', 'langchain', 'openai', 'gpt', 'api', 'language', 'techniques', 'used', 'python', 'models', 'used', 'pandas', 'agent', 'gpt', 'skills', 'used', 'python', 'streamlit', 'streamlit', 'deployment', 'langchain', 'web', 'servers', 'used', 'streamlit', 'technical', 'challenges', 'faced', 'project', 'execution', 'make', 'tool', 'follow', 'standards', 'terms', 'financial', 'quarters', 'currency', 'human', 'readable', 'values', 'instead', 'exponential', 'values', 'technical', 'challenges', 'solved', 'challenge', 'solved', 'decreasing', 'temperature', 'pandas', 'ag ...
# Positive word found: leading
# Positive word found: leading
# Negative word found: problem
# Positive word found: friendly
# Positive word found: capable
# Positive word found: insightful
# Positive word found: facilitate
# Positive word found: seamless
# Positive word found: gain
# Positive word found: valuable
# Negative word found: anomaly
# Positive word found: efficient
# Positive word found: ideal
# Negative word found: unnecessary
# Positive word found: prompt
# Positive word found: prompt
# Positive word found: refine
# Positive word found: readable
# Positive word found: prompt
# Positive word found: desirable
# Positive word found: important
# Positive word found: success
# Analyzing content from: https://insights.blackcoffer.com/grafana-dashboard-to-visualize-and-analyze-sensors-data/
# Words to analyze: ['grafana', 'dashboard', 'visualize', 'analyze', 'sensors', 'data', 'client', 'background', 'client', 'a', 'leading', 'tech', 'firm', 'industry', 'type', 'products', 'services', 'consulting', 'software', 'development', 'devops', 'organization', 'size', 'problem', 'client', 'requires', 'a', 'grafana', 'dashboard', 'fetch', 'data', 'a', 'web', 'api', 'providing', 'historical', 'data', 'building', 'automation', 'systems', 'dashboard', 'needs', 'allow', 'entry', 'a', 'target', 'url', 'individual', 'buildings', 'selection', 'a', 'history', 'name', 'a', 'dropdown', 'search', 'bar', 'selectable', 'time', 'displaying', 'history', 'data', 'ability', 'choose', 'various', 'chart', 'types', 'visualization', 'additionally', 'client', 'wants', 'set', 'alarms', 'certain', 'metrics', 'like', 'cpu', 'ram', 'hard', 'disk', 'usage', 'user', 'able', 'view', 'stier', 'api', 'data', 'controlled', 'ip', 'solution', 'meet', 'requirements', 'set', 'a', 'grafana', 'dashboard', 'using', 'grafana', 'api', 'configure', 'dashboard', 'connect', 'web', 'api', 'fetch', 'data', 'based', 'user', 's', 'input', 'target', 'url', 'history', 'name', 'time', 'visualization', 'implement', 'various', 'chart', 'types', 'including', 'bar', 'line', 'scatter', 'plot', 'charts', 'set', 'alarms', 'specific', 'metrics', 'utilize', 'grafana', 's', 'built', 'alerting', 'feature', 'solution', 'architecture', 'deliverables', 'a', 'fully', 'functional', 'grafana', 'dashboard', 'connected', 'web', 'api', 'ability', 'manually', 'enter', 'a', 'target', 'url', 'individual', 'buildings', 'selection', 'history', 'name', 'a', 'dropdown', 'search', 'bar', 'selection', 'time', 'displaying', 'history', 'data', 'various', 'chart', 'types', 'data', 'visualization', 'setup', 'alarms', 'specific', 'metrics', 'tech', 'tools', 'used', 'python', 'grafana', 'grafana', 'api', 'web', 'api', 'historical', 'data', 'building', 'automation', 'systems', 'language', 'techniques', 'used', 'javascript', 'sql', 'skills', 'used', 'data', 'visualization', 'api', 'integration', 'user', 'interface', 'design', 'databases', 'used', 'grafana', 'database', 'technical', 'challenges', 'faced', 'project', 'execution', 'implementing', 'user', 'permissions', 'individual', 'users', 'setting', 'alarms', 'specific', 'metrics', 'technical', 'challenges', 'solved', 'connecting', 'grafana', 'web', 'api', 'used', 'grafana', 'api', 'configured', 'fetch', 'data', 'web', 'api', 'based', 'user', 'input', 'implement', 'user', 'permissions', 'used', 'grafana', 's', 'built', 'user', 'management', 'feature', 'set', 'roles', 'permissions', 'accordingly', 'setting', 'alarms', 'leveraged', 'grafana', 's', 'built', 'alerting', 'feature', 'configured', 'trigger', 'alerts', 'based', 'specific', 'conditions', 'business', 'impact', 'proposed', 'grafana', 'dashboard', 'significantly', 'enhance', 'business', 's', 'ability', 'monitor', 'manage', 'building', 'automation', 'systems', 'providing', 'time', 'data', 'visualization', 'ability', 'set', 'alarms', 'specific', 'metrics', 'business', 'quickly', 'identify', 'address', 'potential', 'issues', 'ensuring', 'optimal', 'system', 'performance', 'efficiency', 'furthermore', 'user', 'specific', 'permissions', 'ensure', 'sensitive', 'data', 'remains', 'secure', 'accessible', 'authorized', 'individuals', 'streamline', 'operations', 'also', 'boost', 'confidence', 'staff', 'members', 'make', 'informed', 'decisions', 'based', 'accurate', 'timely', 'data', 'dashboard', 's', 'flexibility', 'terms', 'selectable', 'history', 'names', 'time', 'ranges', 'allow', 'comprehensive', 'analysis', 'historical', 'data', 'leading', 'improved', 'decision', 'making', 'processes', 'overall', 'solution', 'contribute', 'increased', 'operational', 'efficiency', 'reduced', 'downtime', 'improved', 'customer', 'satisfaction', 'ensuring', 'smooth', 'operation', 'building', 'automation', 'systems', 'project', 'website', 'url', 'https', 'mailhvac', 'postman', 'co', 'workspace', 'team', 'workspace', 'collection', 'ac ...
# Positive word found: leading
# Negative word found: problem
# Positive word found: like
# Negative word found: hard
# Negative word found: plot
# Positive word found: enhance
# Negative word found: issues
# Positive word found: optimal
# Positive word found: sensitive
# Positive word found: secure
# Positive word found: accessible
# Positive word found: boost
# Positive word found: confidence
# Positive word found: accurate
# Positive word found: timely
# Positive word found: flexibility
# Positive word found: comprehensive
# Positive word found: leading
# Positive word found: improved
# Positive word found: improved
# Positive word found: smooth
# Analyzing content from: https://insights.blackcoffer.com/mvp-for-a-software-that-analyses-content-from-audio-pharma-based/
# Words to analyze: ['mvp', 'a', 'software', 'analyses', 'content', 'audio', 'pharma', 'based', 'client', 'background', 'client', 'a', 'leading', 'pharma', 'tech', 'firm', 'industry', 'type', 'healthcare', 'products', 'services', 'pharma', 'apps', 'organization', 'size', 'problem', 'problem', 'lies', 'creating', 'a', 'backend', 'model', 'application', 'records', 'audio', 'responses', 'students', 'uses', 'analyze', 'content', 'backend', 'needs', 'convert', 'audio', 'text', 'transform', 'text', 'analytics', 'kpis', 'handle', 'login', 'logout', 'operations', 'manage', 'analytics', 'api', 'calls', 'application', 'also', 'calculate', 'cosine', 'similarity', 'student', 's', 'response', 'expected', 'response', 'solution', 'solve', 'problem', 'use', 'python', 'primary', 'programming', 'language', 'backend', 'development', 'solution', 'involves', 'several', 'steps', 'audio', 'text', 'conversion', 'use', 'a', 'speech', 'recognition', 'library', 'python', 'speechrecognition', 'convert', 'audio', 'inputs', 'text', 'text', 'analysis', 'converting', 'audio', 'text', 'apply', 'natural', 'language', 'processing', 'nlp', 'techniques', 'analyze', 'text', 'includes', 'sentiment', 'analysis', 'readability', 'analysis', 'named', 'entity', 'recognition', 'ner', 'use', 'libraries', 'like', 'nltk', 'spacy', 'purpose', 'user', 'authentication', 'build', 'a', 'secure', 'authentication', 'system', 'using', 'jwt', 'tokens', 'handling', 'login', 'logout', 'operations', 'api', 'creation', 'use', 'flask', 'a', 'lightweight', 'python', 'framework', 'create', 'apis', 'managing', 'user', 'handling', 'analytics', 'data', 'data', 'storage', 'use', 'a', 'relational', 'database', 'like', 'postgresql', 'store', 'user', 'session', 'data', 'user', 'profiles', 'analytics', 'data', 'deployment', 'finally', 'deploy', 'application', 'a', 'platform', 'like', 'aws', 'google', 'solution', 'architecture', 'deliverables', 'backend', 'model', 'developed', 'using', 'python', 'apis', 'managing', 'user', 'analytics', 'data', 'secure', 'user', 'authentication', 'system', 'system', 'capable', 'converting', 'audio', 'text', 'text', 'analysis', 'capabilities', 'including', 'sentiment', 'analysis', 'readability', 'analysis', 'ner', 'deployed', 'application', 'a', 'platform', 'tech', 'tools', 'used', 'python', 'flask', 'jwt', 'postgresql', 'aws', 'google', 'language', 'techniques', 'used', 'python', 'models', 'used', 'speechrecognition', 'audio', 'text', 'conversion', 'nltk', 'spacy', 'text', 'analysis', 'skills', 'used', 'backend', 'development', 'api', 'creation', 'text', 'sentiment', 'analysis', 'cosine', 'similarity', 'scoring', 'machine', 'learning', 'natural', 'language', 'processing', 'technical', 'challenges', 'faced', 'project', 'execution', 'one', 'challenges', 'faced', 'development', 'ensuring', 'accurate', 'audio', 'text', 'conversion', 'poor', 'audio', 'quality', 'heavy', 'accents', 'make', 'difficult', 'speech', 'recognition', 'algorithms', 'correctly', 'transcribe', 'audio', 'technical', 'challenges', 'solved', 'overcome', 'challenge', 'decided', 'use', 'a', 'robust', 'speech', 'recognition', 'library', 'supports', 'multiple', 'languages', 'dialects', 'additionally', 'implemented', 'a', 'mechanism', 'allow', 'users', 'manually', 'edit', 'transcribed', 'text', 'providing', 'control', 'accuracy', 'transcription', 'business', 'impact', 'implementation', 'backend', 'model', 'significant', 'business', 'impacts', 'enhanced', 'student', 'engagement', 'providing', 'immediate', 'feedback', 'student', 'responses', 'system', 'a', 'engaging', 'learning', 'environment', 'students', 'receive', 'instant', 'insights', 'communication', 'style', 'areas', 'improvement', 'encouraging', 'enhance', 'responses', 'overall', 'academic', 'performance', 'improved', 'learning', 'outcomes', 'detailed', 'analytics', 'provided', 'system', 'aid', 'educators', 'understanding', 'student', 'learning', 'patterns', 'identifying', 'areas', 'students', 'struggle', 'inform', 'instructional', 'strategies', 'curri ...
# Positive word found: leading
# Negative word found: problem
# Negative word found: problem
# Negative word found: lies
# Negative word found: problem
# Positive word found: like
# Positive word found: secure
# Positive word found: like
# Positive word found: like
# Positive word found: secure
# Positive word found: capable
# Positive word found: accurate
# Negative word found: poor
# Negative word found: difficult
# Positive word found: correctly
# Positive word found: robust
# Positive word found: supports
# Positive word found: significant
# Positive word found: enhanced
# Positive word found: engaging
# Positive word found: improvement
# Positive word found: encouraging
# Positive word found: enhance
# Positive word found: improved
# Negative word found: struggle
# Positive word found: leading
# Positive word found: improved
# Positive word found: savings
# Positive word found: like
# Positive word found: valuable
# Positive word found: seamless
# Positive word found: efficient
# Positive word found: enhance
# Positive word found: leading
# Positive word found: positive
# Positive word found: effectively
# Positive word found: successfully
# Analyzing content from: https://insights.blackcoffer.com/data-engineering-and-management-tool-airbyte-with-custom-data-connectors-to-manage-crm-database/
# Words to analyze: ['data', 'engineering', 'management', 'tool', 'airbyte', 'custom', 'data', 'connectors', 'manage', 'crm', 'database', 'client', 'background', 'client', 'a', 'leading', 'tech', 'firm', 'industry', 'type', 'products', 'services', 'consulting', 'software', 'development', 'organization', 'size', 'problem', 'company', 'requires', 'a', 'robust', 'scalable', 'secure', 'data', 'integration', 'solution', 'handle', 'thousands', 'connections', 'need', 'develop', 'airbyte', 'connectors', 'various', 'software', 'applications', 'listed', 'nx', 'integration', 'including', 'join', 'portal', 'clickup', 'coach', 'accountable', 'hubspot', 'quickbooks', 'quickbooks', 'time', 'flow', 'connectors', 'developed', 'python', 'wrapped', 'docker', 'images', 'code', 'housed', 'github', 'automatically', 'applied', 'airbyte', 'execution', 'using', 'a', 'ci', 'cd', 'pipeline', 'github', 'airbyte', 'also', 'need', 'a', 'full', 'production', 'version', 'airbyte', 'hosted', 'google', 'platform', 'gcp', 'kubernetes', 'secured', 'google', 'sign', 'moreover', 'want', 'add', 'custom', 'features', 'airbyte', 'control', 'bigquery', 'projects', 'datasets', 'airbyte', 'bigquery', 'monitored', 'sentry', 'also', 'housed', 'hosted', 'project', 'error', 'reporting', 'monitoring', 'also', 'need', 'develop', 'transformations', 'clean', 'transform', 'data', 'software', 'source', 'client', 's', 'gcp', 'project', 'bigquery', 'code', 'transformations', 'stored', 'github', 'solution', 'propose', 'develop', 'instance', 'airbyte', 'production', 'gcp', 'kubernetes', 'secured', 'using', 'google', 'sign', 'linked', 'organization', 'deploy', 'airbyte', 'using', 'official', 'documentation', 'secure', 'kubernetes', 'setup', 'plan', 'use', 'traefik', 's', 'forwardauth', 'feature', 'next', 'code', 'airbyte', 'python', 'integrations', 'needed', 'software', 'list', 'already', 'gathered', 'api', 'documentation', 'software', 'application', 'started', 'coding', 'integrations', 'initial', 'integration', 'complete', 'document', 'process', 'clickup', 'guide', 'future', 'integrations', 'use', 'github', 'host', 'source', 'code', 'docker', 'images', 'airbyte', 'integrations', 'also', 'use', 'google', 's', 'sentry', 'error', 'reporting', 'monitoring', 'solution', 'architecture', 'deliverables', 'production', 'airbyte', 'instance', 'gcp', 'kubernetes', 'secured', 'airbyte', 'instance', 'using', 'google', 'sign', 'developed', 'airbyte', 'python', 'integrations', 'required', 'software', 'error', 'reporting', 'monitoring', 'setup', 'sentry', 'documentation', 'integration', 'process', 'clickup', 'tech', 'tools', 'used', 'airbyte', 'docker', 'github', 'google', 'platform', 'google', 'sign', 'traefik', 'sentry', 'language', 'techniques', 'used', 'python', 'models', 'used', 'airbyte', 'etl', 'skills', 'used', 'web', 'scraping', 'database', 'management', 'api', 'connectors', 'databases', 'used', 'google', 'bigquery', 'technical', 'challenges', 'faced', 'project', 'execution', 'one', 'challenges', 'anticipate', 'managing', 'scalability', 'system', 'handle', 'thousands', 'connections', 'another', 'challenge', 'could', 'securing', 'system', 'effectively', 'ensuring', 'smooth', 'operation', 'technical', 'challenges', 'solved', 'address', 'scalability', 'issue', 'leverage', 'inherent', 'scalability', 'kubernetes', 'bigquery', 'kubernetes', 'allows', 'us', 'easily', 'scale', 'services', 'based', 'demand', 'bigquery', 'designed', 'handle', 'datasets', 'query', 'loads', 'ensure', 'effective', 'security', 'use', 'google', 'sign', 'user', 'authentication', 'follow', 'practices', 'securing', 'docker', 'containers', 'gcp', 'environment', 'regular', 'audits', 'penetration', 'testing', 'also', 'conducted', 'identify', 'rectify', 'potential', 'security', 'vulnerabilities', 'business', 'impact', 'developing', 'a', 'robust', 'scalable', 'data', 'integration', 'solution', 'using', 'airbyte', 'aim', 'significantly', 'enhance', 'business', 'operations', 'solution', 'enable', 'us', 'efficiently', 'manage', 'analy ...
# Positive word found: leading
# Negative word found: problem
# Positive word found: robust
# Positive word found: secure
# Negative word found: error
# Positive word found: clean
# Positive word found: secure
# Negative word found: error
# Negative word found: error
# Positive word found: effectively
# Positive word found: smooth
# Negative word found: issue
# Positive word found: leverage
# Positive word found: effective
# Positive word found: rectify
# Positive word found: robust
# Positive word found: enhance
# Positive word found: efficiently
# Positive word found: leading
# Positive word found: improved
# Positive word found: sensitive
# Positive word found: protect
# Positive word found: advantage
# Positive word found: advanced
# Positive word found: robust
# Positive word found: enhance
# Positive word found: success
# Analyzing content from: https://insights.blackcoffer.com/text-summarizing-tool-to-scrape-and-summarize-pubmed-medical-papers/
# Words to analyze: ['text', 'summarizing', 'tool', 'scrape', 'summarize', 'pubmed', 'medical', 'papers', 'client', 'background', 'client', 'a', 'leading', 'medical', 'r', 'd', 'firm', 'industry', 'type', 'medical', 'products', 'services', 'r', 'd', 'organization', 'size', 'problem', 'advanced', 'tool', 'designed', 'specifically', 'doctors', 'assist', 'retrieving', 'answers', 'queries', 'powered', 'technologies', 'including', 'web', 'scraping', 'chatgpt', 'assistant', 'aims', 'streamline', 'information', 'retrieval', 'provide', 'valuable', 'insights', 'professionals', 'assistant', 'leverages', 'capabilities', 'facilitate', 'seamless', 'efficient', 'access', 'knowledge', 'information', 'combines', 'web', 'scraping', 'techniques', 'gather', 'relevant', 'data', 'trusted', 'sources', 'chatgpt', 'pubmed', 'providing', 'accurate', 'responses', 'doctors', 'queries', 'query', 'retrieval', 'assistant', 'utilizes', 'web', 'scraping', 'techniques', 'fetch', 'information', 'credible', 'websites', 'academic', 'journals', 'medical', 'databases', 'trusted', 'sources', 'provides', 'doctors', 'immediate', 'access', 'a', 'vast', 'array', 'knowledge', 'resources', 'benefits', 'time', 'efficiency', 'quickly', 'retrieving', 'information', 'answering', 'queries', 'assistant', 'saves', 'valuable', 'time', 'doctors', 'allowing', 'focus', 'patient', 'care', 'critical', 'tasks', 'access', 'knowledge', 'assistant', 'grants', 'doctors', 'easy', 'access', 'a', 'vast', 'repository', 'knowledge', 'ensuring', 'stay', 'updated', 'latest', 'research', 'treatment', 'guidelines', 'practices', 'decision', 'support', 'tool', 'provides', 'valuable', 'insights', 'recommendations', 'assisting', 'doctors', 'making', 'informed', 'decisions', 'diagnosis', 'treatment', 'plans', 'patient', 'management', 'solution', 'address', 'problem', 'build', 'a', 'web', 'scraping', 'tool', 'uses', 'python', 'libraries', 'beautifulsoup', 'selenium', 'openai', 's', 'gpt', 'program', 'work', 'follows', 'a', 'user', 'inputs', 'url', 'report', 'want', 'extract', 'data', 'program', 'sends', 'a', 'get', 'request', 'webpage', 'parses', 'html', 'content', 'using', 'beautifulsoup', 'program', 'identifies', 'relevant', 'sections', 'webpage', 'title', 'introduction', 'report', 'conclusion', 'keywords', 'extracts', 'text', 'content', 'reference', 'linked', 'report', 'program', 'sends', 'a', 'get', 'request', 'reference', 's', 'webpage', 'parses', 'html', 'content', 'program', 'sends', 'a', 'prompt', 'gpt', 'model', 'asking', 'summarize', 'content', 'reference', 'receives', 'a', 'summarized', 'response', 'program', 'collects', 'summarized', 'references', 'adds', 'report', 'program', 'also', 'identifies', 'images', 'associated', 'report', 'downloads', 'finally', 'program', 'creates', 'a', 'document', 'adds', 'collected', 'information', 'including', 'summarized', 'references', 'downloaded', 'images', 'document', 'solution', 'architecture', 'deliverables', 'a', 'fully', 'functional', 'web', 'scraping', 'tool', 'extract', 'data', 'a', 'given', 'webpage', 'generate', 'a', 'report', 'a', 'detailed', 'documentation', 'explaining', 'use', 'tool', 'kind', 'data', 'extract', 'tech', 'tools', 'used', 'python', 'beautifulsoup', 'selenium', 'openai', 's', 'gpt', 'language', 'techniques', 'used', 'python', 'models', 'used', 'openai', 's', 'gpt', 'skills', 'used', 'web', 'scraping', 'natural', 'language', 'processing', 'machine', 'learning', 'technical', 'challenges', 'faced', 'project', 'execution', 'handling', 'dynamic', 'websites', 'load', 'content', 'javascript', 'managing', 'rate', 'limits', 'captchas', 'imposed', 'target', 'websites', 'ensuring', 'accuracy', 'relevance', 'summarized', 'content', 'generated', 'gpt', 'model', 'technical', 'challenges', 'solved', 'using', 'selenium', 'interact', 'javascript', 'rendered', 'content', 'target', 'websites', 'implementing', 'strategies', 'bypass', 'rate', 'limits', 'captchas', 'tuning', 'parameters', 'gpt', 'model', 'improve', 'quality', 'summarized', 'content', 'bus ...
# Positive word found: leading
# Negative word found: problem
# Positive word found: advanced
# Positive word found: valuable
# Positive word found: facilitate
# Positive word found: seamless
# Positive word found: efficient
# Positive word found: trusted
# Positive word found: accurate
# Positive word found: credible
# Positive word found: trusted
# Positive word found: benefits
# Positive word found: valuable
# Positive word found: patient
# Negative word found: critical
# Positive word found: easy
# Positive word found: support
# Positive word found: valuable
# Positive word found: recommendations
# Positive word found: patient
# Negative word found: problem
# Positive word found: work
# Positive word found: prompt
# Positive word found: dynamic
# Negative word found: limits
# Negative word found: limits
# Positive word found: improve
# Positive word found: significant
# Positive word found: positive
# Positive word found: streamlined
# Negative word found: complex
# Positive word found: improved
# Positive word found: comprehensive
# Positive word found: instrumental
# Positive word found: accurate
# Positive word found: reputation
# Positive word found: improved
# Positive word found: effectiveness
# Positive word found: success
# Analyzing content from: https://insights.blackcoffer.com/7up7down-10updown-snakes-and-ladder-games-built-using-oops/
# Words to analyze: ['snakes', 'ladder', 'games', 'built', 'using', 'oops', 'client', 'background', 'client', 'a', 'leading', 'game', 'development', 'firm', 'industry', 'type', 'gaming', 'software', 'products', 'services', 'gaming', 'software', 'development', 'organization', 'size', 'problem', 'client', 'sends', 'records', 'millions', 'sports', 'bets', 'time', 'world', 'api', 'bets', 'recorded', 'mysql', 'servers', 'tasked', 'processing', 'calculating', 'expected', 'profit', 'loss', 'pnl', 'per', 'bets', 'records', 'sport', 'goal', 'analyze', 'records', 'time', 'api', 'calculate', 'pnl', 'per', 'game', 'records', 'history', 'provided', 'api', 'requires', 'building', 'a', 'serverless', 'application', 'python', 'similar', 'reads', 'bets', 'records', 'updates', 'pnl', 'time', 'within', 'milliseconds', 'records', 'need', 'updated', 'application', 'capable', 'handling', 'records', 'bets', 'per', 'different', 'games', 'pnl', 'needing', 'updated', 'game', 'separately', 'solution', 'address', 'problem', 'propose', 'developing', 'a', 'python', 'based', 'serverless', 'application', 'leverages', 'machine', 'learning', 'models', 'time', 'pnl', 'calculation', 'application', 'use', 'mysql', 'database', 'store', 'retrieve', 'betting', 'records', 'employ', 'parallel', 'computing', 'techniques', 'ensure', 'efficient', 'processing', 'volumes', 'data', 'application', 'also', 'utilize', 'apis', 'fetch', 'time', 'data', 'update', 'pnl', 'accordingly', 'application', 'follow', 'steps', 'connect', 'mysql', 'database', 'access', 'betting', 'records', 'use', 'api', 'fetch', 'time', 'betting', 'data', 'process', 'data', 'using', 'python', 'scripts', 'apply', 'machine', 'learning', 'models', 'predict', 'outcome', 'bet', 'calculate', 'pnl', 'bet', 'according', 'predicted', 'outcome', 'update', 'pnl', 'mysql', 'database', 'time', 'solution', 'architecture', 'deliverables', 'a', 'python', 'based', 'serverless', 'application', 'time', 'pnl', 'calculation', 'interface', 'visualizing', 'calculated', 'pnl', 'time', 'documentation', 'detailing', 'use', 'maintain', 'application', 'tech', 'tools', 'used', 'python', 'writing', 'serverless', 'application', 'mysql', 'storing', 'retrieving', 'betting', 'records', 'machine', 'learning', 'models', 'predicting', 'outcome', 'bets', 'language', 'techniques', 'used', 'python', 'models', 'used', 'oops', 'skills', 'used', 'database', 'analysis', 'api', 'development', 'design', 'optimize', 'mysql', 'database', 'python', 'programming', 'write', 'serverless', 'application', 'oops', 'make', 'game', 'functioning', 'algorithms', 'databases', 'used', 'sql', 'technical', 'challenges', 'faced', 'project', 'execution', 'one', 'challenges', 'faced', 'handling', 'volume', 'data', 'coming', 'time', 'overcome', 'employed', 'parallel', 'computing', 'techniques', 'efficiently', 'process', 'data', 'another', 'challenge', 'updating', 'pnl', 'mysql', 'database', 'time', 'solved', 'designing', 'application', 'update', 'pnl', 'immediately', 'calculated', 'technical', 'challenges', 'solved', 'addressed', 'volume', 'data', 'challenge', 'using', 'parallel', 'computing', 'techniques', 'allowed', 'us', 'process', 'a', 'number', 'records', 'simultaneously', 'ensuring', 'efficient', 'data', 'handling', 'solve', 'time', 'pnl', 'update', 'issue', 'designed', 'application', 'update', 'pnl', 'immediately', 'calculated', 'ensured', 'pnl', 'always', 'date', 'meeting', 'requirement', 'time', 'pnl', 'calculation', 'business', 'impact', 'implementation', 'proposed', 'python', 'based', 'serverless', 'application', 'time', 'pnl', 'calculation', 'significant', 'positive', 'impacts', 'business', 'operations', 'firstly', 'application', 'enabled', 'us', 'process', 'analyze', 'millions', 'sports', 'bets', 'time', 'enhancing', 'decision', 'making', 'capabilities', 'allowing', 'quicker', 'responses', 'changes', 'betting', 'market', 'improved', 'ability', 'predict', 'outcomes', 'adjust', 'betting', 'strategies', 'accordingly', 'secondly', 'application', 'significantly', 'r ...
# Positive word found: leading
# Negative word found: problem
# Negative word found: loss
# Positive word found: capable
# Negative word found: problem
# Positive word found: efficient
# Positive word found: efficiently
# Positive word found: efficient
# Negative word found: issue
# Positive word found: significant
# Positive word found: positive
# Positive word found: quicker
# Positive word found: improved
# Positive word found: faster
# Positive word found: timely
# Positive word found: led
# Positive word found: competitive
# Positive word found: successful
# Positive word found: led
# Positive word found: efficient
# Positive word found: accurate
# Positive word found: timely
# Positive word found: improved
# Positive word found: welcome
# Analyzing content from: https://insights.blackcoffer.com/data-studio-dashboard-with-a-data-pipeline-tool-synced-with-podio-using-custom-webhooks-and-google-cloud-function/
# Words to analyze: ['data', 'studio', 'dashboard', 'a', 'data', 'pipeline', 'tool', 'synced', 'podio', 'using', 'custom', 'webhooks', 'google', 'function', 'client', 'background', 'client', 'a', 'leading', 'retail', 'firm', 'industry', 'type', 'retail', 'products', 'services', 'retail', 'business', 'e', 'commerce', 'organization', 'size', 'problem', 'client', 'needs', 'a', 'consolidated', 'kpi', 'dashboard', 'aggregates', 'data', 'various', 'applications', 'saas', 'products', 'currently', 'data', 'scattered', 'across', 'different', 'platforms', 'making', 'difficult', 'track', 'performance', 'indicators', 'kpis', 'effectively', 'client', 'wants', 'a', 'dashboard', 'automatically', 'updates', 'data', 'eliminating', 'need', 'updates', 'dashboard', 'contain', 'separate', 'tabs', 'current', 'tickets', 'customer', 'satisfaction', 'leads', 'conversion', 'company', 'records', 'finances', 'additionally', 'client', 'wants', 'use', 'google', 'functions', 'sync', 'data', 'regularly', 'podio', 'data', 'app', 'google', 'solution', 'proposed', 'solution', 'involves', 'creation', 'a', 'kpi', 'dashboard', 'google', 'serve', 'a', 'central', 'hub', 'client', 's', 'data', 'dashboard', 'populated', 'data', 'various', 'sources', 'including', 'google', 'podio', 'data', 'app', 'data', 'organized', 'separate', 'tabs', 'representing', 'a', 'different', 'aspect', 'business', 'dashboard', 'designed', 'automatically', 'update', 'data', 'removing', 'need', 'updates', 'process', 'begins', 'obtaining', 'access', 'data', 'google', 'data', 'accessed', 'a', 'list', 'kpis', 'visualized', 'prepared', 'data', 'google', 'connected', 'google', 'data', 'studio', 'dashboard', 'visualization', 'dashboard', 'designed', 'align', 'client', 's', 'goals', 'prioritizing', 'important', 'kpis', 'positioning', 'top', 'dashboard', 'dashboard', 'also', 'protected', 'prevent', 'accidental', 'changes', 'ensuring', 'data', 'added', 'changed', 'designated', 'data', 'collaborators', 'invited', 'email', 'specific', 'roles', 'assigned', 'ensure', 'effective', 'collaboration', 'dashboard', 'customized', 'aligned', 'colors', 'fonts', 'enhance', 'appearance', 'authority', 'addition', 'dashboard', 'webhooks', 'created', 'podio', 'data', 'app', 'deployed', 'a', 'google', 'function', 'enable', 'regular', 'data', 'synchronization', 'podio', 'data', 'app', 'google', 'ensuring', 'dashboard', 'always', 'date', 'latest', 'data', 'solution', 'architecture', 'deliverables', 'end', 'end', 'data', 'pipeline', 'kpi', 'dashboard', 'google', 'separate', 'tabs', 'current', 'tickets', 'customer', 'satisfaction', 'leads', 'conversion', 'company', 'records', 'finances', 'automatic', 'update', 'functionality', 'eliminate', 'need', 'updates', 'webhook', 'podio', 'data', 'app', 'deployed', 'a', 'google', 'function', 'sync', 'data', 'regularly', 'tech', 'tools', 'used', 'python', 'google', 'google', 'data', 'studio', 'google', 'functions', 'podio', 'data', 'app', 'language', 'techniques', 'used', 'python', 'javascript', 'skills', 'used', 'data', 'analysis', 'data', 'visualization', 'functions', 'api', 'integration', 'databases', 'used', 'bigquery', 'technical', 'challenges', 'faced', 'project', 'execution', 'one', 'challenges', 'ensuring', 'dashboard', 'could', 'seamlessly', 'integrate', 'data', 'various', 'sources', 'update', 'automatically', 'another', 'challenge', 'designing', 'dashboard', 'a', 'aligns', 'client', 's', 'goals', 'presents', 'data', 'a', 'clear', 'actionable', 'manner', 'technical', 'challenges', 'solved', 'challenge', 'addressed', 'connecting', 'data', 'sources', 'google', 'setting', 'dashboard', 'automatically', 'update', 'data', 'achieved', 'using', 'google', 'data', 'studio', 'google', 'functions', 'challenge', 'addressed', 'focusing', 'design', 'organization', 'dashboard', 'ensuring', 'aligns', 'client', 's', 'goals', 'presents', 'data', 'a', 'clear', 'actionable', 'manner', 'achieved', 'prioritizing', 'important', 'kpis', 'positioning', 'top', 'dashboard', 'presenting', 'supporting', 'data ...
# Positive word found: leading
# Negative word found: problem
# Negative word found: difficult
# Positive word found: effectively
# Positive word found: leads
# Positive word found: important
# Positive word found: top
# Negative word found: accidental
# Positive word found: effective
# Positive word found: enhance
# Positive word found: leads
# Positive word found: clear
# Positive word found: clear
# Positive word found: important
# Positive word found: top
# Positive word found: supporting
# Positive word found: improved
# Negative word found: struggling
# Negative word found: difficult
# Positive word found: comprehensive
# Positive word found: streamlined
# Positive word found: valuable
# Positive word found: improved
# Positive word found: improvements
# Positive word found: led
# Positive word found: enhanced
# Positive word found: accurate
# Positive word found: timely
# Positive word found: effectively
# Positive word found: significant
# Positive word found: leading
# Positive word found: improved
# Positive word found: welcome
# Analyzing content from: https://insights.blackcoffer.com/end-to-end-tool-to-optimize-routing-and-planning-of-field-engineers-using-googles-cvrp-tw-algorithm/
# Words to analyze: ['end', 'end', 'tool', 'optimize', 'routing', 'planning', 'engineers', 'using', 'google', 's', 'cvrp', 'tw', 'algorithm', 'client', 'background', 'client', 'a', 'leading', 'hardware', 'firm', 'industry', 'type', 'products', 'services', 'consulting', 'support', 'hardware', 'installations', 'organization', 'size', 'problem', 'client', 'specializes', 'installing', 'blinds', 'related', 'products', 'customers', 'homes', 'currently', 'struggling', 'scheduling', 'appointments', 'efficiently', 'due', 'a', 'variety', 'factors', 'location', 'installation', 'duration', 'team', 'member', 'availability', 'customer', 'preferences', 'need', 'a', 'tool', 'suggest', 'optimal', 'schedules', 'based', 'criteria', 'adapt', 'changes', 'customers', 'approve', 'reject', 'proposed', 'appointment', 'times', 'goal', 'create', 'a', 'proof', 'concept', 'a', 'route', 'job', 'planning', 'model', 'potentially', 'streamline', 'scheduling', 'process', 'make', 'a', 'significant', 'impact', 'business', 'operations', 'solution', 'address', 'challenge', 'propose', 'developing', 'a', 'proof', 'concept', 'a', 'route', 'job', 'planning', 'model', 'model', 'based', 'concept', 'constrained', 'vehicle', 'routing', 'problem', 'time', 'windows', 'cvrp', 'tw', 'a', 'well', 'established', 'approach', 'operations', 'research', 'logistics', 'model', 'take', 'a', 'dataset', 'could', 'extracted', 'a', 'google', 'sheet', 'converted', 'a', 'csv', 'file', 'generate', 'optimal', 'schedules', 'development', 'process', 'involve', 'several', 'stages', 'understanding', 'data', 'll', 'analyze', 'data', 'identify', 'relevant', 'variables', 'constraints', 'include', 'locations', 'installations', 'duration', 'installations', 'availability', 'team', 'members', 'customer', 'preferences', 'defining', 'objective', 'constraints', 'objective', 'minimize', 'total', 'travel', 'time', 'maximize', 'number', 'installations', 'completed', 'within', 'a', 'given', 'time', 'constraints', 'include', 'geographical', 'distances', 'locations', 'working', 'hours', 'team', 'members', 'specific', 'requirements', 'installation', 'implementing', 'algorithm', 'll', 'use', 'optimization', 'algorithm', 'traveling', 'salesman', 'problem', 'tsp', 'solver', 'find', 'optimal', 'routes', 'algorithm', 'consider', 'possible', 'routes', 'choose', 'one', 'meets', 'objectives', 'adhering', 'constraints', 'running', 'simulations', 'ensure', 'feasibility', 'model', 'll', 'run', 'simulations', 'using', 'different', 'scenarios', 'adjust', 'parameters', 'needed', 'saving', 'output', 'final', 'output', 'suggested', 'schedules', 'reviewed', 'approved', 'relevant', 'parties', 'terms', 'technology', 'll', 'use', 'python', 'a', 'popular', 'language', 'data', 'analysis', 'machine', 'learning', 'll', 'also', 'use', 'anaconda', 'distribution', 'provides', 'a', 'powerful', 'environment', 'scientific', 'computing', 'data', 'analysis', 'solution', 'architecture', 'deliverables', 'a', 'python', 'script', 'implementing', 'cvrp', 'tw', 'model', 'test', 'data', 'scripts', 'simulating', 'different', 'scenarios', 'documentation', 'explaining', 'use', 'model', 'interpret', 'results', 'tech', 'tools', 'used', 'python', 'primary', 'programming', 'language', 'anaconda', 'python', 'distribution', 'used', 'data', 'analysis', 'machine', 'learning', 'visual', 'studio', 'code', 'code', 'editor', 'used', 'development', 'google', 'app', 'script', 'deployment', 'integrated', 'google', 'language', 'techniques', 'used', 'python', 'models', 'used', 'constrained', 'vehicle', 'routing', 'problem', 'time', 'windows', 'cvrp', 'tw', 'skills', 'used', 'data', 'analysis', 'machine', 'learning', 'optimization', 'algorithms', 'python', 'programming', 'databases', 'used', 'csv', 'google', 'data', 'initially', 'stored', 'a', 'csv', 'file', 'easily', 'imported', 'python', 'using', 'libraries', 'like', 'pandas', 'technical', 'challenges', 'faced', 'project', 'execution', 'one', 'challenges', 'anticipated', 'dealing', 'complexity', 'variability', 'data', 'lo ...
# Positive word found: leading
# Positive word found: support
# Negative word found: problem
# Negative word found: struggling
# Positive word found: efficiently
# Positive word found: variety
# Positive word found: optimal
# Positive word found: approve
# Negative word found: reject
# Positive word found: significant
# Negative word found: problem
# Positive word found: well
# Positive word found: optimal
# Negative word found: problem
# Positive word found: optimal
# Positive word found: popular
# Positive word found: powerful
# Positive word found: integrated
# Negative word found: problem
# Positive word found: like
# Positive word found: flexible
# Positive word found: enough
# Positive word found: approve
# Negative word found: reject
# Positive word found: advanced
# Positive word found: meaningful
# Positive word found: flexible
# Positive word found: efficient
# Positive word found: significant
# Positive word found: positive
# Negative word found: errors
# Positive word found: quicker
# Positive word found: improved
# Positive word found: enhanced
# Positive word found: better
# Positive word found: led
# Positive word found: savings
# Negative word found: unexpected
# Negative word found: unavailable
# Positive word found: valuable
# Positive word found: improvement
# Positive word found: helped
# Negative word found: issues
# Positive word found: enhance
# Positive word found: improvements
# Positive word found: skilled
# Negative word found: unskilled
# Positive word found: leading
# Positive word found: successful
# Positive word found: efficiently
# Positive word found: effectively
# Positive word found: helped
# Positive word found: clear
# Analyzing content from: https://insights.blackcoffer.com/end-to-end-tool-to-predict-biofuel-prices-using-ieso-data/
# ...
# Positive word found: leading
# Positive word found: positive
# Negative word found: negative
# Positive word found: positive
# Negative word found: negative
# Positive word found: like
# Negative word found: issue
# Positive word found: positive
# Negative word found: negative
# Positive word found: sublime
# Positive word found: reliable
# Positive word found: effective
# Positive word found: work
# Positive word found: worked
# Positive word found: positive
# Negative word found: negative
# Negative word found: plot
# Negative word found: plot
# Analyzing content from: https://insights.blackcoffer.com/population-and-community-survey-of-america/
# Words to analyze: ['population', 'community', 'survey', 'client', 'background', 'client', 'a', 'leading', 'marketing', 'firm', 'industry', 'type', 'marketing', 'services', 'consulting', 'services', 'marketing', 'consultant', 'organization', 'size', 'project', 'objective', 'project', 'population', 'community', 'survey', 'objective', 'perform', 'data', 'abstraction', 'data', 'structurization', 'data', 'preprocessing', 'data', 'cleaning', 'combining', 'data', 'years', 'listed', 'finally', 'presenting', 'insights', 'data', 'exploratory', 'data', 'analysis', 'project', 'description', 'project', 'population', 'community', 'survey', 'task', 'involved', 'fetching', 'json', 'unformatted', 'csv', 'data', 'numerous', 'web', 'links', 'needed', 'process', 'data', 'handling', 'nested', 'json', 'data', 'conversion', 'json', 'data', 'dataframe', 'performing', 'certain', 'pandas', 'operation', 'feature', 'selection', 'structuring', 'data', 'concat', 'data', 'one', 'csv', 'file', 'handle', 'missing', 'value', 'mapping', 'another', 'dataset', 'finally', 'perform', 'certain', 'data', 'visualization', 'exploratory', 'data', 'analysis', 'solution', 'module', 'data', 'abstraction', 'process', 'data', 'abstraction', 'involves', 'collecting', 'data', 'numerous', 'web', 'links', 'viewing', 'data', 'using', 'json', 'viewer', 'tree', 'format', 'module', 'data', 'chunking', 'integration', 'unable', 'process', 'data', 'pandas', 'performed', 'data', 'chunking', 'chunksize', 'rows', 'a', 'time', 'likewise', 'performed', 'years', 'data', 'till', 'finally', 'combined', 'dataframes', 'one', 'containing', 'data', 'module', 'handling', 'complexity', 'nested', 'data', 'format', 'unformatted', 'csv', 'files', 'handling', 'unformatted', 'csv', 'proper', 'comma', 'separated', 'format', 'data', 'formed', 'dataframe', 'produced', 'merging', 'years', 'contains', 'a', 'lot', 'nested', 'json', 'data', 'certain', 'attributes', 'performed', 'normalization', 'nested', 'json', 'forming', 'naming', 'based', 'attributes', 'module', 'data', 'cleaning', 'preprocessing', 'involves', 'handling', 'missing', 'value', 'contraction', 'mapping', 'another', 'dataset', 'fill', 'missing', 'column', 'handling', 'inf', 'inf', 'within', 'dataset', 'attributes', 'forming', 'a', 'column', 'based', 'passing', 'formula', 'attributes', 'module', 'data', 'analysis', 'step', 'involves', 'forming', 'a', 'correlation', 'matrix', 'understand', 'relation', 'numeric', 'attributes', 'performed', 'exploratory', 'data', 'analysis', 'correlated', 'attributes', 'understand', 'pattern', 'relation', 'project', 'deliverables', 'completion', 'project', 'provided', 'final', 'preprocessed', 'csv', 'files', 'ipython', 'files', 'preprocessed', 'dataset', 'dataset', 'data', 'visualization', 'preprocessed', 'dataset', 'preprocessed', 'dataset', 'data', 'visualization', 'tools', 'used', 'jupyter', 'notebook', 'anaconda', 'notepad', 'sublime', 'text', 'brackets', 'python', 'json', 'viewer', 'language', 'techniques', 'used', 'python', 'etl', 'techniques', 'advanced', 'excel', 'formatting', 'models', 'used', 'project', 'population', 'community', 'survey', 'developed', 'a', 'software', 'model', 'makes', 'project', 'quality', 'reliable', 'cost', 'effective', 'software', 'model', 'rad', 'rapid', 'application', 'development', 'model', 'model', 'project', 'follows', 'a', 'rad', 'model', 'model', 'forming', 'loop', 'end', 'start', 'also', 'project', 'based', 'prototyping', 'without', 'specific', 'planning', 'rad', 'model', 'less', 'attention', 'paid', 'planning', 'priority', 'given', 'development', 'tasks', 'targets', 'developing', 'software', 'a', 'span', 'time', 'advantages', 'rad', 'model', 'o', 'changing', 'requirements', 'accommodated', 'o', 'progress', 'measured', 'o', 'iteration', 'time', 'use', 'powerful', 'rad', 'tools', 'o', 'productivity', 'fewer', 'people', 'a', 'time', 'o', 'reduced', 'development', 'time', 'o', 'increases', 'reusability', 'components', 'o', 'initial', 'reviews', 'occur', 'o', 'encourages', 'custome ...
# Positive word found: leading
# Negative word found: unable
# Positive word found: proper
# Positive word found: sublime
# Positive word found: advanced
# Positive word found: excel
# Positive word found: reliable
# Positive word found: effective
# Positive word found: rapid
# Positive word found: advantages
# Positive word found: progress
# Positive word found: powerful
# Negative word found: issues
# Positive word found: proper
# Negative word found: plot
# Negative word found: plot
# Negative word found: plot
# Negative word found: plot
# Positive word found: like
# Negative word found: plot
# Negative word found: plot
# Negative word found: plot
# Analyzing content from: https://insights.blackcoffer.com/google-lsa-api-data-automation-and-dashboarding/
# Words to analyze: ['google', 'lsa', 'api', 'data', 'automation', 'dashboarding', 'client', 'background', 'client', 'a', 'leading', 'marketing', 'firm', 'industry', 'type', 'marketing', 'services', 'consulting', 'services', 'marketing', 'consultant', 'organization', 'size', 'project', 'objective', 'project', 'objective', 'perform', 'api', 'data', 'abstraction', 'using', 'google', 'lsa', 'api', 'gcp', 'automation', 'data', 'fetching', 'storing', 'bigquery', 'basis', 'storing', 'historical', 'data', 'active', 'companies', 'fetching', 'customer', 'report', 'storing', 'data', 'basis', 'bigquery', 'also', 'storing', 'historical', 'data', 'companies', 'perform', 'linear', 'regression', 'modelling', 'historical', 'data', 'companies', 'storing', 'modeling', 'summary', 'google', 'sheet', 'a', 'structured', 'manner', 'basecamp', 'automation', 'lsa', 'data', 'creating', 'bi', 'dashboard', 'data', 'studio', 'live', 'historical', 'modelling', 'customer', 'report', 'data', 'companies', 'project', 'description', 'project', 'task', 'obtain', 'account', 'report', 'detailed', 'lead', 'report', 'a', 'specific', 'dates', 'using', 'google', 'local', 'service', 'ads', 'api', 'service', 'google', 'platform', 'need', 'integrate', 'google', 'bigquery', 'database', 'storing', 'mcc', 'data', 'companies', 'a', 'basis', 'storing', 'historical', 'data', 'active', 'companies', 'also', 'notifying', 'clients', 'email', 'passing', 'messages', 'containing', 'account', 'data', 'a', 'message', 'format', 'basecamp', 'message', 'campfire', 'respective', 'company', 'projects', 'api', 'python', 'programming', 'deploying', 'script', 'heroku', 'server', 'automating', 'task', 'creating', 'bi', 'dashboard', 'data', 'studio', 'connecting', 'bigquery', 'creating', 'live', 'dashboard', 'historical', 'dashboard', 'companies', 'historical', 'data', 'companies', 'linear', 'regression', 'modelling', 'needs', 'perform', 'create', 'modelling', 'dashboard', 'companies', 'data', 'studio', 'needs', 'exploratory', 'data', 'analysis', 'companies', 'historical', 'data', 'store', 'customer', 'account', 'report', 'message', 'lead', 'phone', 'lead', 'a', 'basis', 'script', 'needs', 'created', 'deployed', 'heroku', 'also', 'need', 'store', 'historical', 'data', 'companies', 'finally', 'create', 'data', 'studio', 'dashboard', 'creating', 'representation', 'dashboard', 'companies', 'involves', 'multiple', 'reports', 'blending', 'multiple', 'data', 'sources', 'big', 'query', 'solution', 'module', 'api', 'data', 'abstraction', 'includes', 'generation', 'access', 'token', 'refresh', 'token', 'scope', 'google', 'adword', 'api', 'authentication', 'connecting', 'google', 'lsa', 'api', 'fetching', 'data', 'json', 'format', 'particular', 'account', 'name', 'based', 'assigned', 'api', 'url', 'fetching', 'data', 'likewise', 'generating', 'a', 'script', 'would', 'handle', 'data', 'generation', 'active', 'accounts', 'based', 'customer', 'id', 'module', 'data', 'imputation', 'storing', 'converting', 'json', 'data', 'pandas', 'data', 'forming', 'a', 'list', 'data', 'active', 'accounts', 'looping', 'deriving', 'certain', 'attributes', 'based', 'handling', 'missing', 'inf', 'values', 'finally', 'storing', 'data', 'google', 'big', 'query', 'database', 'within', 'respective', 'table', 'accounts', 'using', 'bigquery', 'api', 'module', 'data', 'storing', 'bigquery', 'notification', 'automation', 'task', 'automate', 'notifications', 'sent', 'email', 'basecamp', 'data', 'transferred', 'database', 'a', 'basis', 'deploying', 'script', 'heroku', 'server', 'setting', 'time', 'parameters', 'based', 'time', 'zone', 'module', 'automation', 'tools', 'created', 'till', 'i', 'tool', 'automation', 'account', 'report', 'companies', 'a', 'basis', 'scheduling', 'timezone', 'tool', 'storing', 'historical', 'data', 'companies', 'last', 'years', 'till', 'end', 'date', 'set', 'used', 'lsa', 'data', 'a', 'message', 'format', 'campfire', 'respective', 'companies', 'groups', 'store', 'lsa', 'data', 'combined', 'companies', 'messageboa ...
# Positive word found: leading
# Negative word found: regression
# Positive word found: lead
# Negative word found: regression
# Positive word found: lead
# Positive word found: lead
# Positive word found: refresh
# Negative word found: missed
# Positive word found: lead
# Positive word found: like
# Positive word found: sublime
# Positive word found: reliable
# Positive word found: effective
# Positive word found: rapid
# Positive word found: advantages
# Positive word found: progress
# Positive word found: powerful
# Negative word found: issues
# Positive word found: refresh
# Negative word found: inactive
# Negative word found: issue
# Negative word found: plot
# Negative word found: issues
# Negative word found: issues
# Positive word found: refresh
# Positive word found: refresh
# Negative word found: expired
# Positive word found: refresh
# Positive word found: proper
# Positive word found: refresh
# Negative word found: inactive
# Negative word found: issues
# Positive word found: lead
# Negative word found: missed
# Negative word found: error
# Negative word found: issue
# Negative word found: issue
# Negative word found: plot
# Positive word found: like
# Analyzing content from: https://insights.blackcoffer.com/healthcare-data-analysis/
# Words to analyze: ['healthcare', 'data', 'analysis', 'client', 'background', 'client', 'a', 'leading', 'healthcare', 'tech', 'firm', 'industry', 'type', 'healthcare', 'consulting', 'services', 'management', 'consultant', 'organization', 'size', 'project', 'objective', 'objective', 'project', 'find', 'pattern', 'vital', 'signs', 'patients', 'admitted', 'hospital', 'past', 'pattern', 'get', 'ranges', 'help', 'us', 'give', 'warnings', 'project', 'description', 'interested', 'non', 'survivor', 'patients', 'vital', 'signs', 'compare', 'survivor', 'patients', 'find', 'patterns', 'vital', 'signs', 'could', 'better', 'determine', 'patient', 'died', 'ex', 'patient', 'cases', 'died', 'death', 'rate', 'take', 'correlations', 'help', 'us', 'find', 'better', 'patterns', 'define', 'death', 'cases', 'data', 'dataset', 'used', 'analysis', 'taken', 'mimic', 'website', 'dataset', 'correct', 'format', 'want', 'manipulation', 'get', 'data', 'analysis', 'solution', 'approach', 'protect', 'patient', 'confidentiality', 'date', 'time', 'shifted', 'future', 's', 'actual', 'time', 'shifted', 'time', 'column', 'create', 'extra', 'column', 'hour', 'tells', 'us', 'time', 'passed', 'hours', 'since', 'observation', 'icu', 'manipulation', 'final', 'dataset', 'contain', 'vital', 'signs', 'values', 'observation', 'patients', 'time', 'separate', 'column', 'also', 'label', 'fo', 'death', 'another', 'column', 'options', 'missing', 'valuesdrop', 'rows', 'contain', 'values', 'fill', 'missing', 'values', 'method', 'using', 'pandas', 'drop', 'rows', 'contain', 'values', 'fill', 'missing', 'values', 'method', 'using', 'pandas', 'i', 't', 'go', 'option', 'a', 'part', 'data', 'missing', 'values', 'i', 'decided', 'go', 'option', 'fill', 'missing', 'values', 'average', 'upper', 'values', 'i', 'filtered', 'data', 'take', 'patients', 'data', 'died', 'a', 'hospital', 'survive', 'project', 'deliverables', 'performing', 'also', 'include', 'removal', 'impossible', 'outliers', 'come', 'a', 'result', 'analysis', 'result', 'helps', 'build', 'warning', 'system', 'predict', 'condition', 'patients', 'basis', 'score', 'calculated', 'condition', 'using', 'vital', 'sign', 'values', 'tools', 'used', 'google', 'colab', 'notebook', 'language', 'techniques', 'used', 'python', 'skills', 'used', 'data', 'visualization', 'data', 'analysis', 'pandas', 'numpy', 'seaborn', 'databases', 'used', 'sql', 'mongodb', 'web', 'servers', 'used', 'google', 'project', 'snapshots', 'project', 'website', 'url', 'https', 'colab', 'research', 'google', 'com', 'drive', 'usp', 'sharing']
# Positive word found: leading
# Positive word found: survivor
# Positive word found: survivor
# Positive word found: better
# Positive word found: patient
# Negative word found: died
# Positive word found: patient
# Negative word found: died
# Negative word found: death
# Positive word found: better
# Negative word found: death
# Positive word found: correct
# Negative word found: manipulation
# Positive word found: protect
# Positive word found: patient
# Negative word found: manipulation
# Negative word found: death
# Negative word found: died
# Negative word found: impossible
# Negative word found: warning
# Analyzing content from: https://insights.blackcoffer.com/budget-sales-kpi-dashboard-using-power-bi/
# Words to analyze: ['budget', 'kpi', 'dashboard', 'using', 'bi', 'project', 'description', 'data', 'clustered', 'bar', 'chart', 'budget', 'actual', 'value', 'total', 'budget', 'actual', 'value', 'completed', 'ytd', 'data', 'clustered', 'bar', 'chart', 'budget', 'actual', 'value', 'total', 'budget', 'actual', 'value', 'completed', 'history', 'stacked', 'chart', 'total', 'completed', 'dashlet', 'data', 'total', 'budget', 'total', 'actual', 'budget', 'completed', 'dashlet', 'ytd', 'data', 'total', 'ytd', 'budget', 'total', 'ytd', 'actual', 'ytd', 'budget', 'completed', 'dashlet', 'history', 'total', 'completed', 'filters', 'select', 'area', 'select', 'select', 'years', 'completed', 'data', 'visualization', 'deliverables', 'presentationmapdashboardapi', 'integration', 'data', 'visualization', 'tools', 'kibanagoogle', 'data', 'studiomicrosoft', 'excelmicrosoft', 'bi', 'data', 'visualization', 'languages', 'javascriptsqlpythondax', 'demo']
# Analyzing content from: https://insights.blackcoffer.com/amazon-buy-bot-an-automation-ai-tool-to-auto-checkouts/
# Words to analyze: ['amazon', 'buy', 'bot', 'automation', 'tool', 'auto', 'checkouts', 'client', 'background', 'client', 'a', 'leading', 'consulting', 'firm', 'industry', 'type', 'consulting', 'services', 'management', 'consultant', 'organization', 'size', 'project', 'objective', 'objective', 'project', 'build', 'automation', 'tool', 'buy', 'product', 'amazon', 'project', 'description', 'project', 'basically', 'completed', 'using', 'selenium', 'python', 'done', 'write', 'a', 'python', 'script', 'automation', 'using', 'selenium', 'make', 'clicks', 'use', 'logics', 'check', 'item', 'item', 'buys', 'product', 'otherwise', 'repeat', 'process', 'solution', 'a', 'simple', 'python', 'code', 'uses', 'selenium', 'web', 'work', 'project', 'deliverables', 'python', 'code', 'tools', 'used', 'selenium', 'webdriver', 'language', 'techniques', 'used', 'python', 'skills', 'used', 'web', 'scraping', 'selenium', 'project', 'snapshots']
# Positive word found: leading
# Positive word found: work
# All results saved to /content/drive/MyDrive/Assignment/Output_Analysis.xlsx.
